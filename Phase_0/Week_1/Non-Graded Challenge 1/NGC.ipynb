# %%
numbers = [951, 402, 984, 651, 360, 69, 408, 319, 601, 485, 980, 507, 725, 547, 544, 615, 83, 165, 141, 501, 263, 617, 865, 575, 219, 390, 984, 592, 236, 105, 942, 941, 386, 462, 47, 418, 907, 344, 236, 375, 823, 566, 597, 978, 328, 615, 953, 345, 399, 162, 758, 219, 918, 237, 412, 566, 826, 248, 866, 950, 626, 949]
i = numbers
print(i)
# Out:
# [951, 402, 984, 651, 360, 69, 408, 319, 601, 485, 980, 507, 725, 547, 544, 615, 83, 165, 141, 501, 263, 617, 865, 575, 219, 390, 984, 592, 236, 105, 942, 941, 386, 462, 47, 418, 907, 344, 236, 375, 823, 566, 597, 978, 328, 615, 953, 345, 399, 162, 758, 219, 918, 237, 412, 566, 826, 248, 866, 950, 626, 949]

# %%
for i in numbers:
  if i % 2 ==0:
    print(f'{i} merupakan angka genap')
  else:
    print(f'{i} bukan merupakan angka genap')
  if i in [918]:
    break
    print(i)
# Out:
# 951 bukan merupakan angka genap
# 402 merupakan angka genap
# 984 merupakan angka genap
# 651 bukan merupakan angka genap
# 360 merupakan angka genap
# 69 bukan merupakan angka genap
# 408 merupakan angka genap
# 319 bukan merupakan angka genap
# 601 bukan merupakan angka genap
# 485 bukan merupakan angka genap
# 980 merupakan angka genap
# 507 bukan merupakan angka genap
# 725 bukan merupakan angka genap
# 547 bukan merupakan angka genap
# 544 merupakan angka genap
# 615 bukan merupakan angka genap
# 83 bukan merupakan angka genap
# 165 bukan merupakan angka genap
# 141 bukan merupakan angka genap
# 501 bukan merupakan angka genap
# 263 bukan merupakan angka genap
# 617 bukan merupakan angka genap
# 865 bukan merupakan angka genap
# 575 bukan merupakan angka genap
# 219 bukan merupakan angka genap
# 390 merupakan angka genap
# 984 merupakan angka genap
# 592 merupakan angka genap
# 236 merupakan angka genap
# 105 bukan merupakan angka genap
# 942 merupakan angka genap
# 941 bukan merupakan angka genap
# 386 merupakan angka genap
# 462 merupakan angka genap
# 47 bukan merupakan angka genap
# 418 merupakan angka genap
# 907 bukan merupakan angka genap
# 344 merupakan angka genap
# 236 merupakan angka genap
# 375 bukan merupakan angka genap
# 823 bukan merupakan angka genap
# 566 merupakan angka genap
# 597 bukan merupakan angka genap
# 978 merupakan angka genap
# 328 merupakan angka genap
# 615 bukan merupakan angka genap
# 953 bukan merupakan angka genap
# 345 bukan merupakan angka genap
# 399 bukan merupakan angka genap
# 162 merupakan angka genap
# 758 merupakan angka genap
# 219 bukan merupakan angka genap
# 918 merupakan angka genap
